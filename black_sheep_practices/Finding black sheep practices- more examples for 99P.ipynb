# %%
import pandas as pd
import numpy as np
GBQ_PROJECT_ID = '620265099307'

#q = '''SELECT * FROM ebmdatalab.outlier_detection.chem_by_subpara_by_practice_juntoaug17
#WHERE 1=1'''
#df1 = pd.io.gbq.read_gbq(q, GBQ_PROJECT_ID, dialect='standard')
# rows: pct, chemical, subpara, num, denom, ratio (num and denom are items not quantity)
df1 = pd.read_csv('chem_by_subpara_by_practice_juntoaug17',dtype={'subpara': object}) # read from local csv as memory issues with pd.io

q2 = '''SELECT DISTINCT chemical, chemical_code from ebmdatalab.hscic.bnf'''
chem = pd.io.gbq.read_gbq(q2, GBQ_PROJECT_ID, dialect='standard',verbose=False)

q3 = '''SELECT DISTINCT subpara, subpara_code from ebmdatalab.hscic.bnf'''
subp = pd.io.gbq.read_gbq(q3, GBQ_PROJECT_ID, dialect='standard',verbose=False)

# %%
# need to flag where ccgs have not prescribed any items of the denominator in order to clean the data. 

# Step 1: amend the datafrome to include a line for every CCG and every chemical and subparagraph.

# list all subpara-chemical combinations 
a = df1[["subpara", "chemical"]].drop_duplicates()

#list all practices
b = df1[["pct","practice"]].drop_duplicates()

# cross join to make table of all CCGs and all subpara combinations 
a['tmp'] = 1
b['tmp'] = 1
c = b.merge(a, on="tmp").drop('tmp', axis=1) # 237,636 rows

# join to data - need to list every possible chemical against every CCG
data = c.merge(df1, how="left", on=["pct","practice","subpara","chemical"])  # 237,636 rows
data


# Step 2: identify those with zero subparas
# subpara totals by ccg
subpara = df1[["pct","practice","subpara","denom"]].groupby(["subpara","pct","practice"]).max().reset_index() # 42,917 rows

#list all possible subparagraphs and all ccgs
a2 = df1[["subpara"]].drop_duplicates()
a2['tmp'] = 1

# cross join to CCGs to make table of all CCGs and all subpara combinations 
c2 = b.merge(a2, on="tmp").drop('tmp', axis=1) # 56,097 rows

# join to subpara data by ccg to identify subparas prescribed by each ccg.  
d = c2.merge(subpara,how="left", on=["subpara","pct","practice"])

# for subparas never prescribed, replace NAs with zeros so that there is data present to indicate this
d = d.fillna(0)

# join back to original dataset
d2 = d.merge(data, how="left", on=["subpara","pct","practice"], suffixes=("_subpara",""))
# check how many have zero denominators:
# data.loc[(data["denom_subpara"]==0)] # 19,665 rows 

# exclude combinations where denominators are zero THEN replace NAs with 0:
data2 = d2.loc[(d2["denom_subpara"]!=0)]
data2 = data2.fillna(0)
#data2 = data2.set_index(['pct','chemical'])
data2.head(3)
# Out:
#    pct practice  subpara  denom_subpara   chemical   num  denom  ratio
# 0  04V   C82041  0307000           44.0  0307000J0  44.0   44.0    1.0
# 1  04V   C82041  0307000           44.0  0307000K0   0.0    0.0    0.0
# 2  04V   C82041  0307000           44.0  0307000Q0   0.0    0.0    0.0

# %% [markdown]
# # National
# - take ratios of chemical/subparagraph from above
# - calculate the *national* mean ratio and standard deviation for each chemical

# %%
df2_nat = data2[["chemical", "ratio"]].groupby(["chemical"]).describe()
df2_nat.columns = df2_nat.columns.droplevel()
df2_nat.head(3)
# Out:
#             count      mean       std  min  25%    50%  75%  max
# chemical
# 0101010C0  5624.0  0.035670  0.148797  0.0  0.0  0.000  0.0  1.0
# 0101010F0  5624.0  0.003186  0.044284  0.0  0.0  0.000  0.0  1.0
# 0101010G0  5624.0  0.414975  0.394887  0.0  0.0  0.375  0.8  1.0

# %% [markdown]
# - calculate the number of standard deviations each practice is from the national mean, for each chemical

# %%
output_nat = data2.merge(df2_nat[['mean','std']],how='left', left_on=['chemical'],right_index=True)

output_nat['stds_from_mean'] = (output_nat['ratio'] - output_nat['mean']) / output_nat['std']
output_nat = output_nat.dropna().sort_values('stds_from_mean',ascending =False)
output_nat = output_nat.merge(chem, how="left", left_on = "chemical",right_on="chemical_code",suffixes=(""," name"))
output_nat = output_nat.merge(subp, how="left", left_on = "subpara",right_on="subpara_code",suffixes=(""," name"))
output_nat = output_nat.drop(['subpara','denom_subpara','chemical'],axis=1)
output_nat = output_nat.set_index('practice')
#output_nat.head(3)

# %% [markdown]
# ## 99P
# ### More than usual

# %% [markdown]
# - filter out ones with small ratio

# %%
output_nat.loc[(output_nat.pct=='99P')
               &(output_nat.denom>200)
               &(output_nat['mean']>0.01)].sort_values('stds_from_mean',
                                                       ascending =False).head(20)
# Out:
#           pct    num   denom     ratio      mean       std  stds_from_mean  \
# practice
# L83012    99P  293.0   478.0  0.612971  0.017529  0.034551       17.233945
# L83643    99P  136.0   281.0  0.483986  0.049498  0.043056       10.091244
# L83663    99P  164.0   561.0  0.292335  0.039735  0.025490        9.909595
# L83134    99P  711.0  1087.0  0.654094  0.051798  0.074624        8.071075
# L83023    99P  186.0   653.0  0.284839  0.017529  0.034551        7.736790
# L83099    99P  807.0  1375.0  0.586909  0.051798  0.074624        7.170764
# L83136    99P  185.0   765.0  0.241830  0.025756  0.031765        6.802342
# L83098    99P   38.0   244.0  0.155738  0.011232  0.023091        6.258055
# L83050    99P  326.0   662.0  0.492447  0.027746  0.074263        6.257540
# L83007    99P  176.0   229.0  0.768559  0.125677  0.103972        6.183209
# L83112    99P  131.0   262.0  0.500000  0.073830  0.069217        6.157030
# L83024    99P  265.0   520.0  0.509615  0.010901  0.081056        6.152741
# L83673    99P  132.0   290.0  0.455172  0.059498  0.065346        6.055087
# L83106    99P  208.0   286.0  0.727273  0.062705  0.110848        5.995319
# L83627    99P   30.0   251.0  0.119522  0.012784  0.018311        5.829072
# L83643    99P  142.0   292.0  0.486301  0.060699  0.073205        5.813864
# L83075    99P   91.0   307.0  0.296417  0.017173  0.049105        5.686618
# L83020    99P  212.0   312.0  0.679487  0.125677  0.103972        5.326522
# L83663    99P   81.0   416.0  0.194712  0.017529  0.034551        5.128213
# L83129    99P   95.0   490.0  0.193878  0.017529  0.034551        5.104075
#
#                                 chemical name chemical_code  \
# practice
# L83012                            Telmisartan     0205052Q0
# L83643                             Nifedipine     0206020R0
# L83663               Paroxetine Hydrochloride     0403030P0
# L83134            Lercanidipine Hydrochloride     0206020L0
# L83023                            Telmisartan     0205052Q0
# L83099            Lercanidipine Hydrochloride     0206020L0
# L83136                   Dabigatran Etexilate     0208020X0
# L83098                Triamcinolone Acetonide     1202010T0
# L83050                             Ketoprofen     100302010
# L83007                       Isophane Insulin     0601012S0
# L83112                Alfuzosin Hydrochloride     0704010A0
# L83024                              Influenza     1404000H0
# L83673                Trazodone Hydrochloride     0403010X0
# L83106                 Glycopyrronium Bromide     0301020S0
# L83627              Lofepramine Hydrochloride     0403010R0
# L83643             Promethazine Hydrochloride     0304010W0
# L83075    Metformin Hydrochloride/Sitagliptin     0601023AD
# L83020                       Isophane Insulin     0601012S0
# L83663                            Telmisartan     0205052Q0
# L83129                            Telmisartan     0205052Q0
#
#                                       subpara name subpara_code
# practice
# L83012         Angiotensin-II Receptor Antagonists      0205052
# L83643                    Calcium-Channel Blockers      0206020
# L83663    Selective Serotonin Re-Uptake Inhibitors      0403030
# L83134                    Calcium-Channel Blockers      0206020
# L83023         Angiotensin-II Receptor Antagonists      0205052
# L83099                    Calcium-Channel Blockers      0206020
# L83136                         Oral Anticoagulants      0208020
# L83098                 Drugs Used In Nasal Allergy      1202010
# L83050    Rubefacients,Top NSAIDS,Capsaicin & Poul      1003020
# L83007       Intermediate And Long-Acting Insulins      0601012
# L83112                 Drugs For Urinary Retention      0704010
# L83024                       Vaccines And Antisera      1404000
# L83673    Tricyclic & Related Antidepressant Drugs      0403010
# L83106              Antimuscarinic Bronchodilators      0301020
# L83627    Tricyclic & Related Antidepressant Drugs      0403010
# L83643                              Antihistamines      0304010
# L83075                    Other Antidiabetic Drugs      0601023
# L83020       Intermediate And Long-Acting Insulins      0601012
# L83663         Angiotensin-II Receptor Antagonists      0205052
# L83129         Angiotensin-II Receptor Antagonists      0205052

# %% [markdown]
# ### Less than usual

# %% [markdown]
# - filter out ones with small ratio

# %%
output_nat.loc[(output_nat.pct=='99P')
               &(output_nat.denom>200)
               &(output_nat['mean']<0.99)].sort_values('stds_from_mean',
                                                       ascending =True).head(20)
# Out:
#           pct    num   denom     ratio      mean       std  stds_from_mean  \
# practice
# L83112    99P  131.0   262.0  0.500000  0.884759  0.084858       -4.534128
# L83673    99P  123.0   290.0  0.424138  0.805378  0.090115       -4.230574
# L83134    99P  312.0  1087.0  0.287029  0.708416  0.130218       -3.236014
# L83136    99P  115.0   213.0  0.539906  0.822748  0.089521       -3.159482
# L83128    99P   33.0   265.0  0.124528  0.715778  0.189366       -3.122261
# L83015    99P   42.0   247.0  0.170040  0.805329  0.204129       -3.112188
# L83002    99P  782.0  1309.0  0.597403  0.875431  0.090323       -3.078170
# L83673    99P   40.0   427.0  0.093677  0.399537  0.102324       -2.989135
# L83065    99P  477.0   573.0  0.832461  0.945259  0.038063       -2.963484
# L83076    99P    2.0   477.0  0.004193  0.313202  0.105334       -2.933618
# L83081    99P  149.0   266.0  0.560150  0.822748  0.089521       -2.933343
# L83099    99P  450.0  1375.0  0.327273  0.708416  0.130218       -2.926962
# L83038    99P  343.0   559.0  0.613596  0.875431  0.090323       -2.898889
# L83643    99P   93.0   281.0  0.330961  0.708416  0.130218       -2.898639
# L83089    99P  259.0   459.0  0.564270  0.822748  0.089521       -2.887323
# L83643    99P  276.0   491.0  0.562118  0.805378  0.090115       -2.699424
# L83106    99P   60.0   286.0  0.209790  0.715778  0.189366       -2.672011
# L83647    99P  130.0   205.0  0.634146  0.875431  0.090323       -2.671364
# L83023    99P  531.0  1458.0  0.364198  0.708416  0.130218       -2.643400
# L83003    99P   19.0   299.0  0.063545  0.536016  0.182937       -2.582693
#
#                         chemical name chemical_code  \
# practice
# L83112       Tamsulosin Hydrochloride     0704010U0
# L83673    Amitriptyline Hydrochloride     0403010B0
# L83134                     Amlodipine     0206020A0
# L83136                    Amoxicillin     0501013B0
# L83128                     Tiotropium     0301020Q0
# L83015                       Baclofen     1002020C0
# L83002                Alendronic Acid     0606020A0
# L83673        Citalopram Hydrobromide     0403030D0
# L83065                     Salbutamol     0301011R0
# L83076         Tramadol Hydrochloride     040702040
# L83081                    Amoxicillin     0501013B0
# L83099                     Amlodipine     0206020A0
# L83038                Alendronic Acid     0606020A0
# L83643                     Amlodipine     0206020A0
# L83089                    Amoxicillin     0501013B0
# L83643    Amitriptyline Hydrochloride     0403010B0
# L83106                     Tiotropium     0301020Q0
# L83647                Alendronic Acid     0606020A0
# L83023                     Amlodipine     0206020A0
# L83003                          Senna     0106020M0
#
#                                       subpara name subpara_code
# practice
# L83112                 Drugs For Urinary Retention      0704010
# L83673    Tricyclic & Related Antidepressant Drugs      0403010
# L83134                    Calcium-Channel Blockers      0206020
# L83136                  Broad-Spectrum Penicillins      0501013
# L83128              Antimuscarinic Bronchodilators      0301020
# L83015                   Skeletal Muscle Relaxants      1002020
# L83002             Bisphosphonates and Other Drugs      0606020
# L83673    Selective Serotonin Re-Uptake Inhibitors      0403030
# L83065                  Selective Beta(2)-Agonists      0301011
# L83076                           Opioid Analgesics      0407020
# L83081                  Broad-Spectrum Penicillins      0501013
# L83099                    Calcium-Channel Blockers      0206020
# L83038             Bisphosphonates and Other Drugs      0606020
# L83643                    Calcium-Channel Blockers      0206020
# L83089                  Broad-Spectrum Penicillins      0501013
# L83643    Tricyclic & Related Antidepressant Drugs      0403010
# L83106              Antimuscarinic Bronchodilators      0301020
# L83647             Bisphosphonates and Other Drugs      0606020
# L83023                    Calcium-Channel Blockers      0206020
# L83003                         Stimulant Laxatives      0106020

# %% [markdown]
# # Within CCGs
# - take ratios of chemical/subparagraph from top
# - calculate the *CCG level* mean ratio and standard deviation for each chemical
# - *all* results from here have rows with small ratio filtered out

# %%
df2 = data2[["pct","chemical", "ratio"]].groupby(["pct","chemical"],sort=False).describe()
df2.columns = df2.columns.droplevel()
df2.head(3)
# Out:
#                count      mean       std       min       25%  50%  75%  \
# pct chemical
# 04V 0307000J0   47.0  0.985675  0.027347  0.891892  0.980487  1.0  1.0
#     0307000K0   47.0  0.006574  0.014032  0.000000  0.000000  0.0  0.0
#     0307000Q0   47.0  0.000000  0.000000  0.000000  0.000000  0.0  0.0
#
#                     max
# pct chemical
# 04V 0307000J0  1.000000
#     0307000K0  0.066667
#     0307000Q0  0.000000

# %% [markdown]
# - calculate the number of standard deviations each practice is from the CCG level mean, for each chemical

# %%
output = data2.merge(df2[['mean','std']],how='left', left_on=['pct','chemical'],right_index=True)

output['stds_from_mean'] = (output['ratio'] - output['mean']) / output['std']
output = output.dropna().sort_values('stds_from_mean',ascending =False)
output = output.merge(chem, how="left", left_on = "chemical",right_on="chemical_code",suffixes=(""," name"))
output = output.merge(subp, how="left", left_on = "subpara",right_on="subpara_code",suffixes=(""," name"))
output = output.drop(['subpara','denom_subpara','chemical'],axis=1)
output = output.set_index('practice')
#output.head(3)

# %% [markdown]
# ## 99P
# ### More than usual

# %%
output.loc[(output.pct=='99P')
           &(output.denom>200)
           &(output['mean']>0.01)].sort_values('stds_from_mean',
                                               ascending =False).head(20)
# Out:
#           pct    num   denom     ratio      mean       std  stds_from_mean  \
# practice
# L83024    99P  265.0   520.0  0.509615  0.010224  0.054215        9.211343
# L83663    99P  164.0   561.0  0.292335  0.031725  0.029198        8.925740
# L83012    99P  293.0   478.0  0.612971  0.018599  0.069770        8.519005
# L83113    99P   98.0   230.0  0.426087  0.026975  0.053875        7.408123
# L83073    99P  113.0   497.0  0.227364  0.016114  0.030845        6.848756
# L83136    99P  185.0   765.0  0.241830  0.025481  0.032314        6.695251
# L83643    99P  136.0   281.0  0.483986  0.080926  0.060801        6.629179
# L83651    99P   91.0   377.0  0.241379  0.022427  0.034682        6.313059
# L83673    99P  132.0   290.0  0.455172  0.070876  0.061679        6.230630
# L83643    99P  113.0   667.0  0.169415  0.018555  0.025513        5.912975
# L83050    99P  326.0   662.0  0.492447  0.036006  0.077837        5.864096
# L83627    99P   30.0   251.0  0.119522  0.016626  0.017866        5.759352
# L83112    99P  131.0   262.0  0.500000  0.103098  0.071532        5.548566
# L83643    99P   50.0   272.0  0.183824  0.024533  0.028898        5.512112
# L83651    99P   23.0   221.0  0.104072  0.010503  0.017697        5.287278
# L83112    99P   64.0   462.0  0.138528  0.015903  0.023572        5.202111
# L83134    99P  711.0  1087.0  0.654094  0.098824  0.106922        5.193195
# L83072    99P  150.0  1777.0  0.084412  0.018206  0.012904        5.130736
# L83134    99P  598.0  1172.0  0.510239  0.091090  0.084767        4.944730
# L83092    99P  189.0  1387.0  0.136265  0.023772  0.022844        4.924509
#
#                         chemical name chemical_code  \
# practice
# L83024                      Influenza     1404000H0
# L83663       Paroxetine Hydrochloride     0403030P0
# L83012                    Telmisartan     0205052Q0
# L83113        Diethylamine Salicylate     1003020I0
# L83073                      Glipizide     0601021P0
# L83136           Dabigatran Etexilate     0208020X0
# L83643                     Nifedipine     0206020R0
# L83651                       Etodolac     1001010E0
# L83673        Trazodone Hydrochloride     0403010X0
# L83643                   Escitalopram     0403030X0
# L83050                     Ketoprofen     100302010
# L83627      Lofepramine Hydrochloride     0403010R0
# L83112        Alfuzosin Hydrochloride     0704010A0
# L83643                      Meloxicam     1001010AA
# L83651        Buspirone Hydrochloride     0401020B0
# L83112                            NaN           NaN
# L83134    Lercanidipine Hydrochloride     0206020L0
# L83072                     Carvedilol     020400080
# L83134           Perindopril Erbumine     0205051M0
# L83092      Hydroxyzine Hydrochloride     0304010J0
#
#                                       subpara name subpara_code
# practice
# L83024                       Vaccines And Antisera      1404000
# L83663    Selective Serotonin Re-Uptake Inhibitors      0403030
# L83012         Angiotensin-II Receptor Antagonists      0205052
# L83113    Rubefacients,Top NSAIDS,Capsaicin & Poul      1003020
# L83073                               Sulfonylureas      0601021
# L83136                         Oral Anticoagulants      0208020
# L83643                    Calcium-Channel Blockers      0206020
# L83651       Non-Steroidal Anti-Inflammatory Drugs      1001010
# L83673    Tricyclic & Related Antidepressant Drugs      0403010
# L83643    Selective Serotonin Re-Uptake Inhibitors      0403030
# L83050    Rubefacients,Top NSAIDS,Capsaicin & Poul      1003020
# L83627    Tricyclic & Related Antidepressant Drugs      0403010
# L83112                 Drugs For Urinary Retention      0704010
# L83643       Non-Steroidal Anti-Inflammatory Drugs      1001010
# L83651                                 Anxiolytics      0401020
# L83112               Corticosteroids (Respiratory)      0302000
# L83134                    Calcium-Channel Blockers      0206020
# L83072            Beta-Adrenoceptor Blocking Drugs      0204000
# L83134    Angiotensin-Converting Enzyme Inhibitors      0205051
# L83092                              Antihistamines      0304010

# %% [markdown]
# ### Less than usual

# %%
output.loc[(output.pct=='99P')
           &(output.denom>200)
           &(output['mean']<0.99)].sort_values('stds_from_mean',
                                               ascending =True).head(20)
# Out:
#           pct    num   denom     ratio      mean       std  stds_from_mean  \
# practice
# L83073    99P  366.0   497.0  0.736419  0.970214  0.042183       -5.542384
# L83673    99P  123.0   290.0  0.424138  0.813865  0.070350       -5.539809
# L83112    99P  131.0   262.0  0.500000  0.865584  0.073971       -4.942270
# L83039    99P  300.0   421.0  0.712589  0.927178  0.046157       -4.649120
# L83107    99P  205.0   282.0  0.726950  0.927178  0.046157       -4.337980
# L83128    99P   33.0   265.0  0.124528  0.705643  0.143997       -4.035616
# L83065    99P  477.0   573.0  0.832461  0.944131  0.027882       -4.005139
# L83097    99P  128.0   206.0  0.621359  0.884079  0.066316       -3.961650
# L83134    99P  312.0  1087.0  0.287029  0.689802  0.103830       -3.879170
# L83643    99P  276.0   491.0  0.562118  0.813865  0.070350       -3.578479
# L83099    99P  450.0  1375.0  0.327273  0.689802  0.103830       -3.491572
# L83643    99P   93.0   281.0  0.330961  0.689802  0.103830       -3.456052
# L83106    99P   60.0   286.0  0.209790  0.705643  0.143997       -3.443506
# L83673    99P   40.0   427.0  0.093677  0.421976  0.095896       -3.423479
# L83098    99P   13.0   244.0  0.053279  0.478924  0.131163       -3.245172
# L83076    99P   98.0   492.0  0.199187  0.657530  0.145505       -3.150025
# L83023    99P  531.0  1458.0  0.364198  0.689802  0.103830       -3.135945
# L83076    99P    2.0   477.0  0.004193  0.236090  0.076306       -3.039046
# L83136    99P  179.0   247.0  0.724696  0.897460  0.057234       -3.018527
# Y02633    99P   57.0   275.0  0.207273  0.359916  0.051367       -2.971644
#
#                         chemical name chemical_code  \
# practice
# L83073                     Gliclazide     0601021M0
# L83673    Amitriptyline Hydrochloride     0403010B0
# L83112       Tamsulosin Hydrochloride     0704010U0
# L83039                     Furosemide     0202020L0
# L83107                     Furosemide     0202020L0
# L83128                     Tiotropium     0301020Q0
# L83065                     Salbutamol     0301011R0
# L83097                    Finasteride     0604020C0
# L83134                     Amlodipine     0206020A0
# L83643    Amitriptyline Hydrochloride     0403010B0
# L83099                     Amlodipine     0206020A0
# L83643                     Amlodipine     0206020A0
# L83106                     Tiotropium     0301020Q0
# L83673        Citalopram Hydrobromide     0403030D0
# L83098     Beclometasone Dipropionate     1202010C0
# L83076          Candesartan Cilexetil     0205052C0
# L83023                     Amlodipine     0206020A0
# L83076         Tramadol Hydrochloride     040702040
# L83136                    Allopurinol     1001040C0
# Y02633                 Hydrocortisone     1304000V0
#
#                                       subpara name subpara_code
# practice
# L83073                               Sulfonylureas      0601021
# L83673    Tricyclic & Related Antidepressant Drugs      0403010
# L83112                 Drugs For Urinary Retention      0704010
# L83039                              Loop Diuretics      0202020
# L83107                              Loop Diuretics      0202020
# L83128              Antimuscarinic Bronchodilators      0301020
# L83065                  Selective Beta(2)-Agonists      0301011
# L83097           Male Sex Hormones And Antagonists      0604020
# L83134                    Calcium-Channel Blockers      0206020
# L83643    Tricyclic & Related Antidepressant Drugs      0403010
# L83099                    Calcium-Channel Blockers      0206020
# L83643                    Calcium-Channel Blockers      0206020
# L83106              Antimuscarinic Bronchodilators      0301020
# L83673    Selective Serotonin Re-Uptake Inhibitors      0403030
# L83098                 Drugs Used In Nasal Allergy      1202010
# L83076         Angiotensin-II Receptor Antagonists      0205052
# L83023                    Calcium-Channel Blockers      0206020
# L83076                           Opioid Analgesics      0407020
# L83136     Gout & Cytotoxic Induced Hyperiuicaemia      1001040
# Y02633                     Topical Corticosteroids      1304000

# %% [markdown]
# ## Practices that deviate most from their CCG
# ### 99P

# %%
np.abs(output.loc[(output.pct=='99P')&(output.denom>200)&(output['mean']>0.01),['stds_from_mean']]).groupby(level=0).mean().sort_values(['stds_from_mean'],ascending=False).head(20)
# Out:
#           stds_from_mean
# practice
# L83673          1.460568
# L83643          1.394315
# L83012          1.113370
# L83642          1.073722
# L83080          1.002173
# L83663          0.982917
# L83651          0.980097
# L83107          0.965890
# L83023          0.919517
# L83639          0.907021
# L83144          0.901997
# L83068          0.898356
# L83616          0.896563
# L83134          0.885554
# L83039          0.863208
# L83112          0.856416
# Y00568          0.853696
# L83644          0.833977
# L83015          0.821398
# L83143          0.820497
