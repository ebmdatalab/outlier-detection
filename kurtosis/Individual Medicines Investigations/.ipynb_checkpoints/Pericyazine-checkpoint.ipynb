# %%
#import libraries required for analysis
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
from ebmdatalab import bq, charts, maps

# %%
sql = """
SELECT
  month,
  pct,
  practice,
  name,
  address1, 
  address2, 
  address4, 
  address5, 
  postcode,
  SUM(items) AS total_pericyazine
FROM
  ebmdatalab.hscic.normalised_prescribing_standard AS presc
INNER JOIN
  ebmdatalab.hscic.practices prac
ON
  presc.practice = prac.code
  AND (prac.setting = 4)
WHERE
  bnf_code LIKE "0402010P0%" AND
  (month >= "2019-03-01" and month  <= "2019-06-01")
  AND items > 1
GROUP BY
  month,
  pct,
  practice,
  name,
  address1, 
  address2, 
  address4, 
  address5, 
  postcode
ORDER BY
  month,
  practice
"""

pericyazine = bq.cached_read(sql, csv_path='pericyazine_df.csv')
pericyazine['month'] = pericyazine['month'].astype('datetime64[ns]')
pericyazine.head(10)
# Out:
#        month  pct practice                          name  \
# 0 2019-03-01  00J   A83049           QUEENS ROAD SURGERY
# 1 2019-03-01  00J   A83072     LANCHESTER MEDICAL CENTRE
# 2 2019-03-01  13T   A85611        PELAW MEDICAL PRACTICE
# 3 2019-03-01  13T   A86601  DENTON TURRET MEDICAL CENTRE
# 4 2019-03-01  03Q   B82005          PRIORY MEDICAL GROUP
# 5 2019-03-01  03Q   B82021        DALTON TERRACE SURGERY
# 6 2019-03-01  03Q   B82041            BEECH TREE SURGERY
# 7 2019-03-01  02R   B83010    PARKLANDS MEDICAL PRACTICE
# 8 2019-03-01  02R   B83018           IDLE MEDICAL CENTRE
# 9 2019-03-01  02N   B83620             ADDINGHAM SURGERY
#
#                     address1                   address2         address4  \
# 0        QUEENS ROAD SURGERY  83 QUEENS ROAD, BLACKHILL    COUNTY DURHAM
# 1  LANCHESTER MEDICAL CENTRE                DURHAM ROAD    COUNTY DURHAM
# 2     PELAW MEDICAL PRACTICE    7-8 CROXDALE TCE, PELAW      TYNE & WEAR
# 3  DENTON TURRET MEDICAL CTR    10 KENLEY RD, SLATYFORD             None
# 4      PRIORY MEDICAL CENTRE             CORNLANDS ROAD  NORTH YORKSHIRE
# 5                 GLENTWORTH             DALTON TERRACE  NORTH YORKSHIRE
# 6         BEECH TREE SURGERY          68 DONCASTER ROAD  NORTH YORKSHIRE
# 7     PARKLANDS MEDICAL PRAC         30 BUTTERSHAW LANE   WEST YORKSHIRE
# 8        IDLE MEDICAL CENTRE   440 HIGHFIELD ROAD, IDLE   WEST YORKSHIRE
# 9   ADDINGHAM MEDICAL CENTRE    151A MAIN ST, ADDINGHAM             None
#
#   address5  postcode  total_pericyazine
# 0     None   DH8 0BW                  4
# 1     None   DH7 0LP                  6
# 2     None  NE10 0RR                  4
# 3     None   NE5 2UY                  4
# 4     None  YO24 3WX                  6
# 5     None  YO24 4DB                  5
# 6     None   YO8 9AJ                  4
# 7     None   BD6 2DD                  4
# 8     None  BD10 8RU                  4
# 9     None  LS29 0LZ                  3
